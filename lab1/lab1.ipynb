# %% [markdown]
# <hr>
# <center style="font-size:20px;"><b>Лабораторна робота №1</b></center>
# <hr>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <hr>
# <center style="font-size:18px;"><b> Завдання №2 </b></center>
# <hr>

# %% [markdown]
# <p style="font-size:15px;">Задати вершини довільного опуклого 8-кутника на площині.</p>

# %%
octagon = np.array([[3, 4, 1], 
                   [3, 5, 1], 
                   [4, 3, 1], 
                   [4, 6, 1], 
                   [5, 3, 1], 
                   [5, 6, 1], 
                   [6, 4, 1], 
                   [6, 5, 1]])

# %% [markdown]
# <p style="font-size:15px;">Візуалізуємо</p>

# %%
def plot_points(points):
    x = points[:, 0]
    y = points[:, 1]

    plt.scatter(x, y, color='green')

    plt.axhline(y=0, color='gray', linestyle='--')
    plt.axvline(x=0, color='gray', linestyle='--')

    plt.xlabel('X')
    plt.ylabel('Y')

    plt.xlim(-8, 8)
    plt.ylim(-8, 8)

    plt.grid(True)
    
plot_points(octagon)

# %% [markdown]
#  <p style="font-size:15px;">Зменшити його в 1,5 рази.</p>

# %%
scaled_points = octagon / 1.5
plot_points(scaled_points)

# %% [markdown]
# <hr>
# <center style="font-size:18px;"><b> Завдання №3 </b></center>
# <hr>

# %% [markdown]
# <p style="font-size:15px;">Отриманий результат з попереднього пункту симетрично відобразити відносно початку координат.</p>

# %%
transformation_matrix = np.array([[-1, 0, 0],
                                  [0, -1, 0],
                                  [0, 0, 1]])  
symmetric_points = np.dot(scaled_points, transformation_matrix[:, :-1])
plot_points(symmetric_points)

# %% [markdown]
# <hr>
# <center style="font-size:18px;"><b> Завдання №4 </b></center>
# <hr>

# %% [markdown]
# <p style="font-size:15px;">Задати похилу пряму двома точками на площині.</p>

# %%
plot_points(scaled_points)
    
point1 = np.array([0, -2])
point2 = np.array([6, 4])

k = (point2[1] - point1[1]) / (point2[0] - point1[0])
b = point1[1] - k*point1[0]

x_values = [point1[0], point2[0]]
y_values = [point1[1], point2[1]]
phi = np.arctan(k)

plt.plot(x_values, y_values, color='black')

plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.show()

# %%
vector = [0, -2], [6, 4]
vector = np.hstack((vector, 1))
#матриця перенесення

M = ([[1, 0, 0],
     [0, 1, -b],
     [0, 0, 1]])

octagon_1 = np.dot(scaled_points, M)

line_1 = np.dot(vector, M)
print(line_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 vector = [0, -2], [6, 4]
# ----> 2 vector = np.hstack((vector, 1))
#       3 #матриця перенесення
#       5 M = ([[1, 0, 0],
#       6      [0, 1, -b],
#       7      [0, 0, 1]])
#
# File <__array_function__ internals>:200, in hstack(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/shape_base.py:370, in hstack(tup, dtype, casting)
#     368     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     369 else:
# --> 370     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %% [markdown]
# <hr>
# <center style="font-size:18px;"><b> Завдання №6 </b></center>
# <hr>

# %%
df = pd.read_csv('var_06.csv')
